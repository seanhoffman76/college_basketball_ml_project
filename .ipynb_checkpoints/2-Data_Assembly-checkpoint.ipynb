# %% [markdown]
# # Data Assembly and Evaluation
#
# ### Combine the boxscores for the seasons being used.
#
# ### Evaluate the fields for completeness (looking at number of NaN values).
#
# ### Generate distributions on key statistics to review for problem data.

# %%
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')

# %%
path = r'C:\Users\seanh\college_basketball_ml_project\output\boxscores'                 # use your path
all_files = glob.iglob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

box_hist_df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True, sort=False)

box_hist_df.head()
# Out:
#    Unnamed: 0  away_assist_percentage  away_assists  away_block_percentage  \
# 0         0.0                     NaN             8                    NaN
# 1         1.0                     NaN            12                    NaN
# 2         2.0                    57.1            12                    5.7
# 3         3.0                    54.2            13                    2.3
# 4         4.0                    73.9            17                   16.7
#
#    away_blocks  away_defensive_rating  away_defensive_rebound_percentage  \
# 0            4                    NaN                                NaN
# 1            1                    NaN                                NaN
# 2            2                  122.5                               68.2
# 3            1                   89.2                               50.0
# 4            4                  102.9                               89.7
#
#    away_defensive_rebounds  away_effective_field_goal_percentage  \
# ...

# %%
print(len(box_hist_df))
# Out:
# 205236

# %%
box_hist_df.dtypes
# Out:
# Unnamed: 0                                float64
# away_assist_percentage                    float64
# away_assists                                int64
# away_block_percentage                     float64
# away_blocks                                 int64
# away_defensive_rating                     float64
# away_defensive_rebound_percentage         float64
# away_defensive_rebounds                     int64
# away_effective_field_goal_percentage      float64
# away_field_goal_attempts                    int64
# away_field_goal_percentage                float64
# away_field_goals                            int64
# away_free_throw_attempt_rate              float64
# away_free_throw_attempts                    int64
# away_free_throw_percentage                float64
# away_free_throws                            int64
# away_losses                                 int64
# away_minutes_played                         int64
# away_offensive_rating                     float64
# ...

# %%
print(box_hist_df.isnull().sum(axis=0).sort_values(ascending=False))
# Out:
# away_ranking                              190938
# home_ranking                              185060
# Unnamed: 0                                102618
# away_offensive_rebound_percentage           4658
# home_minutes_played                         4658
# away_turnover_percentage                    4658
# away_true_shooting_percentage               4658
# away_total_rebound_percentage               4658
# away_three_point_attempt_rate               4658
# away_steal_percentage                       4658
# away_offensive_rating                       4658
# away_free_throw_attempt_rate                4658
# away_effective_field_goal_percentage        4658
# away_defensive_rebound_percentage           4658
# away_defensive_rating                       4658
# away_block_percentage                       4658
# away_assist_percentage                      4658
# location                                    2594
# home_offensive_rebound_percentage            162
# ...

# %%
for col in box_hist_df.columns: 
    print(col)
# Out:
# Unnamed: 0
# away_assist_percentage
# away_assists
# away_block_percentage
# away_blocks
# away_defensive_rating
# away_defensive_rebound_percentage
# away_defensive_rebounds
# away_effective_field_goal_percentage
# away_field_goal_attempts
# away_field_goal_percentage
# away_field_goals
# away_free_throw_attempt_rate
# away_free_throw_attempts
# away_free_throw_percentage
# away_free_throws
# away_losses
# away_minutes_played
# away_offensive_rating
# away_offensive_rebound_percentage
# away_offensive_rebounds
# away_personal_fouls
# away_points
# away_ranking
# away_steal_percentage
# away_steals
# away_three_point_attempt_rate
# away_three_point_field_goal_attempts
# away_three_point_field_goal_percentage
# away_three_point_field_goals
# away_total_rebound_percentage
# away_total_rebounds
# away_true_shooting_percentage
# away_turnover_percentage
# away_turnovers
# away_two_point_field_goal_attempts
# away_two_point_field_goal_percentage
# away_two_point_field_goals
# ...

# %%
for col in box_hist_df.columns: 
    print(box_hist_df.dtypes)
# Out:
# Unnamed: 0                                float64
# away_assist_percentage                    float64
# away_assists                                int64
# away_block_percentage                     float64
# away_blocks                                 int64
# away_defensive_rating                     float64
# away_defensive_rebound_percentage         float64
# away_defensive_rebounds                     int64
# away_effective_field_goal_percentage      float64
# away_field_goal_attempts                    int64
# away_field_goal_percentage                float64
# away_field_goals                            int64
# away_free_throw_attempt_rate              float64
# away_free_throw_attempts                    int64
# away_free_throw_percentage                float64
# away_free_throws                            int64
# away_losses                                 int64
# away_minutes_played                         int64
# away_offensive_rating                     float64
# ...

# %%
box_hist_df.home_three_point_field_goals.fillna(0, inplace = True) 
box_hist_df.home_three_point_field_goals = pd.to_numeric(box_hist_df.home_three_point_field_goals,errors='coerce')

box_hist_df.home_three_point_field_goal_attempts.fillna(0, inplace = True) 
box_hist_df.home_three_point_field_goal_attempts = pd.to_numeric(box_hist_df.home_three_point_field_goal_attempts,errors='coerce')

box_hist_df.home_two_point_field_goal_attempts.fillna(0, inplace = True) 
box_hist_df.home_two_point_field_goal_attempts = pd.to_numeric(box_hist_df.home_two_point_field_goal_attempts,errors='coerce')

for col in box_hist_df.columns: 
    print(box_hist_df.dtypes)
# Out:
# Unnamed: 0                                float64
# away_assist_percentage                    float64
# away_assists                                int64
# away_block_percentage                     float64
# away_blocks                                 int64
# away_defensive_rating                     float64
# away_defensive_rebound_percentage         float64
# away_defensive_rebounds                     int64
# away_effective_field_goal_percentage      float64
# away_field_goal_attempts                    int64
# away_field_goal_percentage                float64
# away_field_goals                            int64
# away_free_throw_attempt_rate              float64
# away_free_throw_attempts                    int64
# away_free_throw_percentage                float64
# away_free_throws                            int64
# away_losses                                 int64
# away_minutes_played                         int64
# away_offensive_rating                     float64
# ...

# %% [markdown]
# ### Check some of the key statistics on min and max to make sure they are don't contain bogus data. Seaborn's 'distplot' provides us with a simple histogram with a kernel density estimate to illustrate the shape of the distributions.

# %%
# away_wins field distribution

print(np.min(box_hist_df.away_wins))
print(np.max(box_hist_df.away_wins))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)  

plt.grid(True)
sns.distplot(box_hist_df.away_wins, rug=True)

plt.savefig('./figures/box_away_wins.png')
# Out:
# 0
# 38

# %%
# Check the home_wins field

print(np.min(box_hist_df.home_wins))
print(np.max(box_hist_df.home_wins))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)  

plt.grid(True)
sns.distplot(box_hist_df.home_wins, rug=True)

plt.savefig('./figures/box_home_wins.png')
# Out:
# 0
# 38

# %%
# Check the away_points field

print(np.min(box_hist_df.away_points))
print(np.max(box_hist_df.away_points))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)  

plt.grid(True)
sns.distplot(box_hist_df.away_points, rug=True)

plt.savefig('./figures/box_away_points.png')
# Out:
# 12
# 127

# %%
# Check the home_points field

print(np.min(box_hist_df.home_points))
print(np.max(box_hist_df.home_points))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)  

plt.grid(True)
sns.distplot(box_hist_df.home_points, rug=True)

plt.savefig('./figures/box_home_points.png')
# Out:
# 24
# 151

# %%
# Check the away_minutes_played field
# # (a standard game is 40 minutes * 5 players on each team = 200 minutes, and overtime periods are 5 minutes each)

print(np.min(box_hist_df.away_minutes_played))
print(np.max(box_hist_df.away_minutes_played))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_minutes_played, rug=True)

plt.savefig('./figures/box_away_minplayed.png')
# Out:
# 102
# 325

# %%
# Check the home_minutes_played field 
# (a standard game is 40 minutes * 5 players on each team = 200 minutes, and overtime periods are 5 minutes each)

print(np.min(box_hist_df.home_minutes_played))
print(np.max(box_hist_df.home_minutes_played))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_minutes_played, rug=True)

plt.savefig('./figures/box_home_minplayed.png')
# Out:
# 102.0
# 325.0

# %%
# Check the away_total_rebounds field

print(np.min(box_hist_df.away_total_rebounds))
print(np.max(box_hist_df.away_total_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)

sns.distplot(box_hist_df.away_total_rebounds, rug=True)

plt.savefig('./figures/box_away_totrebounds.png')
# Out:
# 6
# 69

# %%
# Check the home_total_rebounds field

print(np.min(box_hist_df.home_total_rebounds))
print(np.max(box_hist_df.home_total_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_total_rebounds, rug=True)

plt.savefig('./figures/box_home_totrebounds.png')
# Out:
# 9
# 71

# %%
# Check the away_personal_fouls field

print(np.min(box_hist_df.away_personal_fouls))
print(np.max(box_hist_df.away_personal_fouls))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_personal_fouls, rug=True)

plt.savefig('./figures/box_away_fouls.png')
# Out:
# 0
# 54

# %%
# Check the home_personal_fouls field

print(np.min(box_hist_df.home_personal_fouls))
print(np.max(box_hist_df.home_personal_fouls))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_personal_fouls, rug=True)

plt.savefig('./figures/box_home_fouls.png')
# Out:
# 3
# 40

# %%
# Check the away_assists field

print(np.min(box_hist_df.away_assists))
print(np.max(box_hist_df.away_assists))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_assists, rug=True)

plt.savefig('./figures/box_away_assists.png')
# Out:
# 0
# 35

# %%
# Check the home_assists field

print(np.min(box_hist_df.home_assists))
print(np.max(box_hist_df.home_assists))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_assists, rug=True)

plt.savefig('./figures/box_home_assists.png')
# Out:
# 1
# 40

# %%
# Check the away_blocks field

print(np.min(box_hist_df.away_blocks))
print(np.max(box_hist_df.away_blocks))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_blocks, rug=True)

plt.savefig('./figures/box_away_blocks.png')
# Out:
# 0
# 18

# %%
# Check the home_blocks field

print(np.min(box_hist_df.home_blocks))
print(np.max(box_hist_df.home_blocks))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_blocks, rug=True)

plt.savefig('./figures/box_home_blocks.png')
# Out:
# 0
# 18

# %%
# Check the away_steals field

print(np.min(box_hist_df.away_steals))
print(np.max(box_hist_df.away_steals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_steals, rug=True)

plt.savefig('./figures/box_away_steals.png')
# Out:
# 0
# 26

# %%
# Check the home_steals field

print(np.min(box_hist_df.home_steals))
print(np.max(box_hist_df.home_steals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_steals, rug=True)

plt.savefig('./figures/box_home_steals.png')
# Out:
# 0
# 37

# %%
# Check the away_turnovers field

print(np.min(box_hist_df.away_turnovers))
print(np.max(box_hist_df.away_turnovers))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_turnovers, rug=True)

plt.savefig('./figures/box_away_turnovers.png')
# Out:
# 1
# 48

# %%
# Check the home_turnovers field

print(np.min(box_hist_df.home_turnovers))
print(np.max(box_hist_df.home_turnovers))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_turnovers, rug=True)

plt.savefig('./figures/box_home_turnovers.png')
# Out:
# 0
# 35

# %%
# Check the away_three_point_field_goals field

print(np.min(box_hist_df.away_three_point_field_goals))
print(np.max(box_hist_df.away_three_point_field_goals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_three_point_field_goals, rug=True)

plt.savefig('./figures/box_away_3FG.png')
# Out:
# 0
# 23

# %%
# Check the home_three_point_field_goals field

print(np.min(box_hist_df.home_three_point_field_goals))
print(np.max(box_hist_df.home_three_point_field_goals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_three_point_field_goals, rug=True)

plt.savefig('./figures/box_home_3FG.png')
# Out:
# 0.0
# 26.0

# %%
# Check the away_field_goals field

print(np.min(box_hist_df.away_field_goals))
print(np.max(box_hist_df.away_field_goals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_field_goals, rug=True)

plt.savefig('./figures/box_away_FG.png')
# Out:
# 3
# 48

# %%
# Check the home_field_goals field

print(np.min(box_hist_df.home_field_goals))
print(np.max(box_hist_df.home_field_goals))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_field_goals, rug=True)

plt.savefig('./figures/box_home_FG.png')
# Out:
# 6
# 58

# %%
# Check the pace field

print(np.min(box_hist_df.pace))
print(np.max(box_hist_df.pace))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.pace, rug=True)

plt.savefig('./figures/box_pace.png')
# Out:
# 46.1
# 130.3

# %%
# Check the away_defensive_rebounds field

print(np.min(box_hist_df.away_defensive_rebounds))
print(np.max(box_hist_df.away_defensive_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_defensive_rebounds, rug=True)

plt.savefig('./figures/box_away_defensive_rebounds.png')
# Out:
# 3
# 49

# %%
# Check the home_defensive_rebounds field

print(np.min(box_hist_df.home_defensive_rebounds))
print(np.max(box_hist_df.home_defensive_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_defensive_rebounds, rug=True)

plt.savefig('./figures/box_home_defensive_rebounds.png')
# Out:
# 4
# 55

# %%
# Check the away_field_goal_attempts field

print(np.min(box_hist_df.away_field_goal_attempts))
print(np.max(box_hist_df.away_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_field_goal_attempts, rug=True)

plt.savefig('./figures/box_away_field_goal_attempts.png')
# Out:
# 28
# 104

# %%
# Check the home_field_goal_attempts field

print(np.min(box_hist_df.home_field_goal_attempts))
print(np.max(box_hist_df.home_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_field_goal_attempts, rug=True)

plt.savefig('./figures/box_home_field_goal_attempts.png')
# Out:
# 27
# 106

# %%
# Check the away_free_throw_attempts field

print(np.min(box_hist_df.away_free_throw_attempts))
print(np.max(box_hist_df.away_free_throw_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_free_throw_attempts, rug=True)

plt.savefig('./figures/box_away_free_throw_attempts.png')
# Out:
# 0
# 65

# %%
# Check the home_free_throw_attempts field

print(np.min(box_hist_df.home_free_throw_attempts))
print(np.max(box_hist_df.home_free_throw_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_free_throw_attempts, rug=True)

plt.savefig('./figures/box_home_free_throw_attempts.png')
# Out:
# 0
# 78

# %%
# Check the away_free_throws field

print(np.min(box_hist_df.away_free_throws))
print(np.max(box_hist_df.away_free_throws))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_free_throws, rug=True)

plt.savefig('./figures/box_away_free_throws.png')
# Out:
# 0
# 47

# %%
# Check the home_free_throws field

print(np.min(box_hist_df.home_free_throws))
print(np.max(box_hist_df.home_free_throws))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_free_throws, rug=True)

plt.savefig('./figures/box_home_free_throws.png')
# Out:
# 0
# 54

# %%
# Check the away_losses field

print(np.min(box_hist_df.away_losses))
print(np.max(box_hist_df.away_losses))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_losses, rug=True)

plt.savefig('./figures/box_away_losses.png')
# Out:
# 0
# 31

# %%
# Check the home_losses field

print(np.min(box_hist_df.home_losses))
print(np.max(box_hist_df.home_losses))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_losses, rug=True)

plt.savefig('./figures/box_home_losses.png')
# Out:
# 0
# 29

# %%
# Check the away_offensive_rebounds field

print(np.min(box_hist_df.away_offensive_rebounds))
print(np.max(box_hist_df.away_offensive_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_offensive_rebounds, rug=True)

plt.savefig('./figures/box_away_offensive_rebounds.png')
# Out:
# 0
# 30

# %%
# Check the home_offensive_rebounds field

print(np.min(box_hist_df.home_offensive_rebounds))
print(np.max(box_hist_df.home_offensive_rebounds))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_offensive_rebounds, rug=True)

plt.savefig('./figures/box_home_offensive_rebounds.png')
# Out:
# 0
# 37

# %%
# Check the away_three_point_field_goal_attempts field

print(np.min(box_hist_df.away_three_point_field_goal_attempts))
print(np.max(box_hist_df.away_three_point_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_three_point_field_goal_attempts, rug=True)

plt.savefig('./figures/box_away_3FG_attempts.png')
# Out:
# 1
# 60

# %%
# Check the home_three_point_field_goal_attempts field

print(np.min(box_hist_df.home_three_point_field_goal_attempts))
print(np.max(box_hist_df.home_three_point_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_three_point_field_goal_attempts, rug=True)

plt.savefig('./figures/box_home_3FG_attempts.png')
# Out:
# 0.0
# 58.0

# %%
# Check the away_two_point_field_goal_attempts field

print(np.min(box_hist_df.away_two_point_field_goal_attempts))
print(np.max(box_hist_df.away_two_point_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.away_two_point_field_goal_attempts, rug=True)

plt.savefig('./figures/box_away_2FG_attempts.png')
# Out:
# 9
# 73

# %%
# Check the home_two_point_field_goal_attempts field

print(np.min(box_hist_df.home_two_point_field_goal_attempts))
print(np.max(box_hist_df.home_two_point_field_goal_attempts))

fig = plt.figure(figsize=(13, 7))    
    
ax = plt.subplot(111)

plt.grid(True)
sns.distplot(box_hist_df.home_two_point_field_goal_attempts, rug=True)

plt.savefig('./figures/box_home_2FG_attempts.png')
# Out:
# 0.0
# 78.0

# %%
box_hist_df.to_csv('output/boxscores/2011-2019-combined_boxscores.csv')
